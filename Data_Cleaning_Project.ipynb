# %%
import pandas as pd

data = {
    'Name': ['Ram', 'Priya', 'Ram', 'Kumar', 'Anu', 'Vijay'],
    'Age': [25, 23, 25, None, 22, 24],
    'City': ['Chennai', 'Madurai', 'Chennai', 'Coimbatore', 'madurai', 'Madurai'],
    'Sales': [5000, 7000, 5000, 8000, 6000, None]
}

df = pd.DataFrame(data)

df.to_csv('sales_data.csv', index=False)

print("Dataset Created Successfully!")
df
# Out:
# Dataset Created Successfully!
#     Name   Age        City   Sales
# 0    Ram  25.0     Chennai  5000.0
# 1  Priya  23.0     Madurai  7000.0
# 2    Ram  25.0     Chennai  5000.0
# 3  Kumar   NaN  Coimbatore  8000.0
# 4    Anu  22.0     madurai  6000.0
# 5  Vijay  24.0     Madurai     NaN

# %%
import pandas as pd

df = pd.read_csv('sales_data.csv')

print("Original Data")
df
# Out:
# Original Data
#     Name   Age        City   Sales
# 0    Ram  25.0     Chennai  5000.0
# 1  Priya  23.0     Madurai  7000.0
# 2    Ram  25.0     Chennai  5000.0
# 3  Kumar   NaN  Coimbatore  8000.0
# 4    Anu  22.0     madurai  6000.0
# 5  Vijay  24.0     Madurai     NaN

# %%
df = df.drop_duplicates()
print("Duplicates Removed")
df
# Out:
# Duplicates Removed
#     Name   Age        City   Sales
# 0    Ram  25.0     Chennai  5000.0
# 1  Priya  23.0     Madurai  7000.0
# 3  Kumar   NaN  Coimbatore  8000.0
# 4    Anu  22.0     madurai  6000.0
# 5  Vijay  24.0     Madurai     NaN

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

df['Sales'] = df['Sales'].fillna(df['Sales'].mean())

print("Missing Values Filled")
df
# Out:
# Missing Values Filled
# /tmp/ipykernel_4022/1506966714.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'] = df['Age'].fillna(df['Age'].mean())
# /tmp/ipykernel_4022/1506966714.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sales'] = df['Sales'].fillna(df['Sales'].mean())
#     Name   Age        City   Sales
# 0    Ram  25.0     Chennai  5000.0
# 1  Priya  23.0     Madurai  7000.0
# 3  Kumar  23.5  Coimbatore  8000.0
# 4    Anu  22.0     madurai  6000.0
# ...

# %%
df['City'] = df['City'].str.title()
print("City Names Corrected")
df
# Out:
# City Names Corrected
# /tmp/ipykernel_4022/2486836177.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['City'] = df['City'].str.title()
#     Name   Age        City   Sales
# 0    Ram  25.0     Chennai  5000.0
# 1  Priya  23.0     Madurai  7000.0
# 3  Kumar  23.5  Coimbatore  8000.0
# 4    Anu  22.0     Madurai  6000.0
# 5  Vijay  24.0     Madurai  6500.0

# %%
df. to_csv('cleaned_data.csv', index=False)
print("Cleaned Data Saved")
# Out:
# Cleaned Data Saved

# %%
import matplotlib.pyplot as plt

city_sales = df.groupby('City')['Sales'].sum()

city_sales.plot(kind='bar')

plt.title('Sales by City')
plt.xlabel('City')
plt.ylabel('Total Sales')

plt.show()

# %%
import matplotlib.pyplot as plt

city_sales = df.groupby('City')['Sales'].sum()

city_sales.plot(kind='bar')

plt.title('Sales by City')
plt.xlabel('City')
plt.ylabel('Total Sales')

plt.savefig('sales_report.png')

print("Chart Saved Successfully")
# Out:
# Chart Saved Successfully

# %%
from google.colab import files
files.download('cleaned_data.csv')

# %%
from google.colab import files
files.download('sales_report.png')

# %%
from google.colab import files
files.download('sales_data.csv')
